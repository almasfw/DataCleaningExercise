# %%
import pandas as pd
import numpy as np
import re

# %%
nominees = pd.read_csv("oscars.csv", encoding='latin1')

# %%
nominees.head()
# Out:
#     _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0  670454353    False   finalized                   3      2/10/15 3:45
# 1  670454354    False   finalized                   3      2/10/15 2:03
# 2  670454355    False   finalized                   3      2/10/15 2:05
# 3  670454356    False   finalized                   3      2/10/15 2:04
# 4  670454357    False   finalized                   3      2/10/15 1:48
#
#            birthplace  birthplace:confidence date_of_birth  \
# 0   Chisinau, Moldova                    1.0   30-Sep-1895
# 1   Glasgow, Scotland                    1.0    2-Feb-1886
# 2   Chisinau, Moldova                    1.0   30-Sep-1895
# 3         Chicago, Il                    1.0   23-Feb-1899
# 4  Salt Lake City, Ut                    1.0   23-Apr-1894
#
#    date_of_birth:confidence race_ethnicity  ...          award  \
# 0                       1.0          White  ...  Best Director
# ...

# %%
nominees.shape
# Out:
# (441, 27)

# %%
birthPlaces = list(nominees["birthplace"])
for i in range(len(birthPlaces)):
    birthPlaces[i] = re.findall(r'\s?([\w\s]+)$', birthPlaces[i])
print(birthPlaces)
# Out:
# [['Moldova'], ['Scotland'], ['Moldova'], ['Il'], ['Ut'], ['Scotland'], ['Italy'], ['Me'], ['Italy'], ['Ca'], ['Italy'], ['Ca'], ['Me'], ['Me'], ['France'], ['Hungary'], ['Ca'], ['New York City'], ['Austria'], ['France'], ['Turkey'], ['Mo'], ['Pa'], ['Pa'], ['Ca'], ['Me'], ['Austria'], ['Turkey'], ['Ks'], ['Ca'], ['England'], ['Il'], ['France'], ['Austria'], ['In'], ['England'], ['England'], ['New York City'], ['In'], ['Austria'], ['Germany'], ['Mn'], ['England'], ['England'], ['Japan'], ['Il'], ['Il'], ['Mn'], ['Mi'], ['Czechoslovakia'], ['Il'], ['Ny'], ['New York City'], ['Tx'], ['Ca'], ['Va'], ['England'], ['Nj'], ['Czechoslovakia'], ['In'], ['New York City'], ['Italy'], ['Md'], ['New York City'], ['Ca'], ['Ny'], ['Ca'], ['Oh'], ['Il'], ['Ny'], ['England'], ['Canada'], ['Oh'], ['England'], ['Ga'], ['Ok'], ['France'], ['New Zealand'], ['Ca'], ['Taiwan'], ['Ny'], ['Mn'], ['England'], ['Ca'], ['England'], ['France'], ['Taiwan'], ['Switzerland'], ['Oh'], ['England'], ['Pa'], ['Mo'], ['
# ...

# %%
for i in range(len(birthPlaces)):
    if (len(birthPlaces[i][0]) <= 2) | (birthPlaces[i][0] == "New York City"):
        nominees.loc[[i], "birthplace"] = "USA"
    else:
        nominees.loc[[i], "birthplace"] = birthPlaces[i]
    #nominees = nominees.replace(nominees["birthplace"][i], birthPlaces[i][0])

# %%
nominees.head()
# Out:
#     _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0  670454353    False   finalized                   3      2/10/15 3:45
# 1  670454354    False   finalized                   3      2/10/15 2:03
# 2  670454355    False   finalized                   3      2/10/15 2:05
# 3  670454356    False   finalized                   3      2/10/15 2:04
# 4  670454357    False   finalized                   3      2/10/15 1:48
#
#   birthplace  birthplace:confidence date_of_birth  date_of_birth:confidence  \
# 0    Moldova                    1.0   30-Sep-1895                       1.0
# 1   Scotland                    1.0    2-Feb-1886                       1.0
# 2    Moldova                    1.0   30-Sep-1895                       1.0
# 3        USA                    1.0   23-Feb-1899                       1.0
# 4        USA                    1.0   23-Apr-1894                       1.0
#
#   race_ethnicity  ...          award  \
# ...

# %%
# nonUS = nominees["birthplace"]
# nonUS = list(dict.fromkeys(nonUS)) #remove duplication
# for i in range(len(nonUS)):
#     if (nonUSA):
#         nonUS.pop(i)
# nonUS = list(nonUS)
# nonUS

# %%
birthPlaces = nominees["birthplace"]
print(birthPlaces)
# Out:
# 0       Moldova
# 1      Scotland
# 2       Moldova
# 3           USA
# 4           USA
#          ...
# 436     England
# 437     England
# 438         USA
# 439         USA
# 440         USA
# Name: birthplace, Length: 441, dtype: object

# %%
baris_sebelum = nominees.shape[0]
print("Jumlah nominee sebelumnya adalah {}.".format(baris_sebelum))

for i in range(len(birthPlaces)):
    if (nominees["birthplace"] == "USA"):
        nominees = nominees.drop(i)
# nominees = nominees.loc[nominees["birthplace"].isin(nonUS)]

baris_sesudah = nominees.shape[0]
print("Jumlah nominee setelah seleksi {}.".format(baris_sesudah))

print("{} nominee yang dihapus!".format(baris_sebelum-baris_sesudah))
# Out:
# Jumlah nominee sebelumnya adalah 441.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-367-40dae431fa9d> in <module>
#       3
#       4 for i in range(len(birthPlaces)):
# ----> 5     if (nominees["birthplace"] == birthPlaces[i]):
#       6         nominees = nominees.drop(i)
#       7 # nominees = nominees.loc[nominees["birthplace"].isin(nonUS)]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1553             "The truth value of a {0} is ambiguous. "
#    1554             "Use a.empty, a.bool(), a.item(), a.any() or a.all().".format(
# -> 1555                 self.__class__.__name__
#    1556             )
#    1557         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
nominees.head()
# Out:
# 0    True
# 1    True
# 2    True
# 5    True
# 6    True
# Name: birthplace, dtype: bool
