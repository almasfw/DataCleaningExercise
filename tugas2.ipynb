# %%
import pandas as pd
import numpy as np
import re

# %%
nominees = pd.read_csv("oscars.csv", encoding='latin1')

# %%
nominees.head()
# Out:
#     _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0  670454353    False   finalized                   3      2/10/15 3:45
# 1  670454354    False   finalized                   3      2/10/15 2:03
# 2  670454355    False   finalized                   3      2/10/15 2:05
# 3  670454356    False   finalized                   3      2/10/15 2:04
# 4  670454357    False   finalized                   3      2/10/15 1:48
#
#            birthplace  birthplace:confidence date_of_birth  \
# 0   Chisinau, Moldova                    1.0   30-Sep-1895
# 1   Glasgow, Scotland                    1.0    2-Feb-1886
# 2   Chisinau, Moldova                    1.0   30-Sep-1895
# 3         Chicago, Il                    1.0   23-Feb-1899
# 4  Salt Lake City, Ut                    1.0   23-Apr-1894
#
#    date_of_birth:confidence race_ethnicity  ...          award  \
# 0                       1.0          White  ...  Best Director
# 1                       1.0          White  ...  Best Director
# 2                       1.0          White  ...  Best Director
# 3                       1.0          White  ...  Best Director
# 4                       1.0          White  ...  Best Director
#
#                                       biourl  birthplace_gold  \
# 0  http://www.nndb.com/people/320/000043191/              NaN
# 1  http://www.nndb.com/people/626/000042500/              NaN
# 2  http://www.nndb.com/people/320/000043191/              NaN
# 3  http://www.nndb.com/people/544/000041421/              NaN
# 4  http://www.nndb.com/people/292/000044160/              NaN
#
#   date_of_birth_gold                           movie           person  \
# 0                NaN             Two Arabian Knights  Lewis Milestone
# 1                NaN                 The Divine Lady      Frank Lloyd
# 2                NaN  All Quiet on the Western Front  Lewis Milestone
# 3                NaN                          Skippy    Norman Taurog
# 4                NaN                        Bad Girl    Frank Borzage
#
#    race_ethnicity_gold religion_gold sexual_orientation_gold  \
# 0                  NaN           NaN                     NaN
# 1                  NaN           NaN                     NaN
# 2                  NaN           NaN                     NaN
# 3                  NaN           NaN                     NaN
# 4                  NaN           NaN                     NaN
#
#   year_of_award_gold
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
#
# [5 rows x 27 columns]

# %%
nominees.shape
# Out:
# (441, 27)

# %%
birthPlaces = list(nominees["birthplace"])
for i in range(len(birthPlaces)):
    birthPlaces[i] = re.findall(r'(\w+)$', birthPlaces[i])
print(birthPlaces)
# Out:
# [['Moldova'], ['Scotland'], ['Moldova'], ['Il'], ['Ut'], ['Scotland'], ['Italy'], ['Me'], ['Italy'], ['Ca'], ['Italy'], ['Ca'], ['Me'], ['Me'], ['France'], ['Hungary'], ['Ca'], ['City'], ['Austria'], ['France'], ['Turkey'], ['Mo'], ['Pa'], ['Pa'], ['Ca'], ['Me'], ['Austria'], ['Turkey'], ['Ks'], ['Ca'], ['England'], ['Il'], ['France'], ['Austria'], ['In'], ['England'], ['England'], ['City'], ['In'], ['Austria'], ['Germany'], ['Mn'], ['England'], ['England'], ['Japan'], ['Il'], ['Il'], ['Mn'], ['Mi'], ['Czechoslovakia'], ['Il'], ['Ny'], ['City'], ['Tx'], ['Ca'], ['Va'], ['England'], ['Nj'], ['Czechoslovakia'], ['In'], ['City'], ['Italy'], ['Md'], ['City'], ['Ca'], ['Ny'], ['Ca'], ['Oh'], ['Il'], ['Ny'], ['England'], ['Canada'], ['Oh'], ['England'], ['Ga'], ['Ok'], ['France'], ['Zealand'], ['Ca'], ['Taiwan'], ['Ny'], ['Mn'], ['England'], ['Ca'], ['England'], ['France'], ['Taiwan'], ['Switzerland'], ['Oh'], ['England'], ['Pa'], ['Mo'], ['England'], ['Oh'
'], ['Mi'], ['Ca'], ['Ia'], ['Nj'], ['Ca'], ['Il'], ['Japan'], ['England'], ['Mo'], ['Pa'], ['Rico'], ['Ny'], ['England'], ['Russia'], ['Mo'], ['Ne'], ['Ma'], ['Ma'], ['Md'], ['Dc'], ['Ia'], ['Oh'], ['Ca'], ['Sweden'], ['City'], ['Ny'], ['England'], ['England'], ['Nj'], ['Ar'], ['Ny'], ['Mn'], ['Nj'], ['England'], ['Ca'], ['Mo'], ['Ma'], ['Ma'], ['Ireland'], ['City'], ['Ny'], ['Ny'], ['Canada'], ['Mo'], ['Nj'], ['France'], ['Ga'], ['England'], ['Ca'], ['Ca'], ['Ny'], ['Wales'], ['Tx'], ['Australia'], ['England'], ['Il'], ['Engl ...

# %%
for i in range(len(birthPlaces)):
    nominees.loc[[i], "birthplace"] = birthPlaces[i]
    #nominees = nominees.replace(nominees["birthplace"][i], birthPlaces[i][0])

# %%
nominees.head()
# Out:
#     _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0  670454353    False   finalized                   3      2/10/15 3:45
# 1  670454354    False   finalized                   3      2/10/15 2:03
# 2  670454355    False   finalized                   3      2/10/15 2:05
# 3  670454356    False   finalized                   3      2/10/15 2:04
# 4  670454357    False   finalized                   3      2/10/15 1:48
#
#   birthplace  birthplace:confidence date_of_birth  date_of_birth:confidence  \
# 0    Moldova                    1.0   30-Sep-1895                       1.0
# 1   Scotland                    1.0    2-Feb-1886                       1.0
# 2    Moldova                    1.0   30-Sep-1895                       1.0
# 3         Il                    1.0   23-Feb-1899                       1.0
# 4         Ut                    1.0   23-Apr-1894                       1.0
#
#   race_ethnicity  ...          award  \
# 0          White  ...  Best Director
# 1          White  ...  Best Director
# 2          White  ...  Best Director
# 3          White  ...  Best Director
# 4          White  ...  Best Director
#
#                                       biourl  birthplace_gold  \
# 0  http://www.nndb.com/people/320/000043191/              NaN
# 1  http://www.nndb.com/people/626/000042500/              NaN
# 2  http://www.nndb.com/people/320/000043191/              NaN
# 3  http://www.nndb.com/people/544/000041421/              NaN
# 4  http://www.nndb.com/people/292/000044160/              NaN
#
#   date_of_birth_gold                           movie           person  \
# 0                NaN             Two Arabian Knights  Lewis Milestone
# 1                NaN                 The Divine Lady      Frank Lloyd
# 2                NaN  All Quiet on the Western Front  Lewis Milestone
# 3                NaN                          Skippy    Norman Taurog
# 4                NaN                        Bad Girl    Frank Borzage
#
#    race_ethnicity_gold religion_gold sexual_orientation_gold  \
# 0                  NaN           NaN                     NaN
# 1                  NaN           NaN                     NaN
# 2                  NaN           NaN                     NaN
# 3                  NaN           NaN                     NaN
# 4                  NaN           NaN                     NaN
#
#   year_of_award_gold
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
#
# [5 rows x 27 columns]

# %%
nonUS = nominees["birthplace"]
for i in range(len(nonUS)):
    if len(nonUS[i]) <= 2:
        nonUS.pop(i)
nonUS = list(nonUS)
nonUS
# Out:
# ['Moldova',
#  'Scotland',
#  'Moldova',
#  'Scotland',
#  'Italy',
#  'Italy',
#  'Italy',
#  'France',
#  'Hungary',
#  'City',
#  'Austria',
#  'France',
#  'Turkey',
#  'Austria',
#  'Turkey',
#  'England',
#  'France',
#  'Austria',
#  'England',
#  'England',
#  'City',
#  'Austria',
#  'Germany',
#  'England',
#  'England',
#  'Japan',
#  'Czechoslovakia',
#  'City',
#  'England',
#  'Czechoslovakia',
#  'City',
#  'Italy',
#  'City',
#  'England',
#  'Canada',
#  'England',
#  'France',
#  'Zealand',
#  'Taiwan',
#  'England',
#  'England',
#  'France',
#  'Taiwan',
#  'Switzerland',
#  'England',
#  'England',
#  'England',
#  'Ukraine',
#  'England',
#  'Hungary',
#  'Wales',
#  'England',
#  'England',
#  'Rico',
#  'City',
#  'Russia',
#  'England',
#  'England',
#  'City',
#  'Austria',
#  'England',
#  'City',
#  'England',
#  'City',
#  'England',
#  'City',
#  'England',
#  'England',
#  'England',
#  'Wales',
#  'City',
#  'Australia',
#  'City',
#  'Italy',
#  'Zealand',
#  'City',
#  'England',
#  'England',
#  'France',
#  'England',
#  'Austria',
#  'England',
#  'Ireland',
#  'City',
#  'Canada',
#  'Wales',
#  'Canada',
#  'Russia',
#  'Mexico',
#  'City',
#  'Mexico',
#  'City',
#  'Wales',
#  'England',
#  'England',
#  'City',
#  'City',
#  'England',
#  'Romania',
#  'City',
#  'City',
#  'England',
#  'City',
#  'Cambodia',
#  'England',
#  'Scotland',
#  'England',
#  'Rico',
#  'England',
#  'Islands',
#  'Australia',
#  'Wales',
#  'Canada',
#  'Canada',
#  'Canada',
#  'Canada',
#  'France',
#  'Germany',
#  'Germany',
#  'India',
#  'Japan',
#  'England',
#  'Sweden',
#  'Japan',
#  'Japan',
#  'City',
#  'India',
#  'City',
#  'Belgium',
#  'Italy',
#  'Sweden',
#  'Germany',
#  'England',
#  'Italy',
#  'England',
#  'India',
#  'England',
#  'England',
#  'England',
#  'City',
#  'England',
#  'City',
#  'England',
#  'England',
#  'Africa',
#  'England',
#  'France',
#  'England',
#  'Israel',
#  'Australia',
#  'City',
#  'City',
#  'Greece',
#  'City',
#  'City',
#  'City',
#  'Japan',
#  'England',
#  'Rico',
#  'England',
#  'Russia',
#  'Sweden',
#  'City',
#  'England',
#  'England',
#  'England',
#  'Ireland',
#  'City',
#  'Canada',
#  'France',
#  'England',
#  'Wales',
#  'Australia',
#  'England',
#  'England',
#  'Spain',
#  'City',
#  'Mexico',
#  'Austria',
#  'City',
#  'City',
#  'City',
#  'England',
#  'England',
#  'England',
#  'England']

# %%
baris_sebelum = nominees.shape[0]
print("Jumlah nominee sebelumnya adalah {}.".format(baris_sebelum))

nominees = nominees.loc[nominees["birthplace"].isin(nonUS)]

baris_sesudah = nominees.shape[0]
print("Jumlah nominee setelah seleksi {}.".format(baris_sesudah))

print("{} nominee yang dihapus!".format(baris_sebelum-baris_sesudah))
# Out:
# Jumlah nominee sebelumnya adalah 441.
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-231-0ceb09d4a276> in <module>
#       2 print("Jumlah nominee sebelumnya adalah {}.".format(baris_sebelum))
#       3
# ----> 4 nominees = nominees.loc[nominees["birthplace"].isin(nonUS)]
#       5
#       6 baris_sesudah = nominees.shape[0]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1422
#    1423             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1424             return self._getitem_axis(maybe_callable, axis=axis)
#    1425
#    1426     def _is_scalar_access(self, key: Tuple):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1797             return self._get_slice_axis(key, axis=axis)
#    1798         elif com.is_bool_indexer(key):
# -> 1799             return self._getbool_axis(key, axis=axis)
#    1800         elif is_list_like_indexer(key):
#    1801
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getbool_axis(self, key, axis)
#    1436         # caller is responsible for ensuring non-None axis
#    1437         labels = self.obj._get_axis(axis)
# -> 1438         key = check_bool_indexer(labels, key)
#    1439         inds, = key.nonzero()
#    1440         try:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in check_bool_indexer(index, key)
#    2409         if mask.any():
#    2410             raise IndexingError(
# -> 2411                 "Unalignable boolean Series provided as "
#    2412                 "indexer (index of the boolean Series and of "
#    2413                 "the indexed object do not match)."
#
# IndexingError: Unalignable boolean Series provided as indexer (index of the boolean Series and of the indexed object do not match).

# %%
nominees.head()
# Out:
# 0    True
# 1    True
# 2    True
# 5    True
# 6    True
# Name: birthplace, dtype: bool
